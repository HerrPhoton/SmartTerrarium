# %%
import sys
sys.path.append("../..")

from src.capture import CameraFrameCapture
from src.configs import CameraConfig

# %%
# camera_source = 'rtsp://192.168.0.194:554/onvif1'
camera_source = 0

# %%
config = CameraConfig(
    source = camera_source
)

# %%
capture = CameraFrameCapture(config)
capture.get_actual_properties()
# Out:
# (640, 480, 30.0)

# %%
capture.save_stream("frames/", interval=2)
# Out:
# (WindowsPath('frames'), 4)
