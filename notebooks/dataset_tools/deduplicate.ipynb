# %%
import sys
sys.path.append("../..")

from src.dataset_tools import ImageDeduplicator

# %%
deduplicator = ImageDeduplicator(verbose=True)
# Out:
# 2025-11-07 16:10:48,265: INFO Device set to cuda ..
# 2025-11-07 16:10:48,324: INFO Initialized: mobilenet_v3_small for feature extraction ..

# %%
deduplicator.find_duplicates(
    image_dir='../../datasets/classification/train/turtle',
    min_similarity_threshold=0.9,
)
# Out:
# 2025-11-07 16:10:48,330: INFO Start: Image encoding generation
# 2025-11-07 16:12:35,705: INFO End: Image encoding generation
# 2025-11-07 16:12:35,908: INFO Start: Calculating cosine similarities...
# 2025-11-07 16:12:36,169: INFO End: Calculating cosine similarities.
# {np.str_('All_about_russian_tortoises_0.jpg'): [],
#  np.str_('All_about_russian_tortoises_1.jpg'): [],
#  np.str_('All_about_russian_tortoises_10.jpg'): [],
#  np.str_('All_about_russian_tortoises_108.jpg'): [],
#  np.str_('All_about_russian_tortoises_109.jpg'): [],
#  np.str_('All_about_russian_tortoises_11.jpg'): [],
#  np.str_('All_about_russian_tortoises_110.jpg'): [np.str_('All_about_russian_tortoises_111.jpg')],
#  np.str_('All_about_russian_tortoises_111.jpg'): [np.str_('All_about_russian_tortoises_110.jpg')],
#  np.str_('All_about_russian_tortoises_112.jpg'): [np.str_('All_about_russian_tortoises_113.jpg')],
#  np.str_('All_about_russian_tortoises_113.jpg'): [np.str_('All_about_russian_tortoises_112.jpg')],
# ...

# %%
deduplicator.visualize_duplicates(4)
