# %%
import sys
sys.path.append("../..")

from src.dataset_tools.image_validator import ImageValidator

# %%
validator = ImageValidator()
validator.cleanup_corrupted_images("D:\\My_Files\\Projects\\nn\\SmartTerrarium\\datasets\\classificaion", verbose=True, dry_run=True)
# Out:
# Найдено 21459 файлов изображений для проверки
# Проверка изображений: 100%|██████████| 21459/21459 [00:38<00:00, 556.48it/s]
# {'total_processed': 21459, 'corrupted_removed': 0, 'removed_files': []}
